# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig1 = plt.figure()

# %%
x = np.linspace(0, 10, 100)
fig1 = plt.figure()
ax1 = fig1.add_axes([0, 0, 1, 0.9])
ax2 = fig1.add_axes([0., 0.4, 1, 0.9])
ax2.plot(x, np.sin(x))
